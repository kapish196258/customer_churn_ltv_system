# %%
from sqlalchemy import create_engine

DATABASE_URL = "postgresql://postgres:Kinkap@@1105@localhost:5432/customer_churn_db"

engine = create_engine(DATABASE_URL)

print("Connection Successful!")
# Out:
# Connection Successful!

# %%
import pandas as pd

df = pd.read_csv("../data/processed/cleaned_telco_data.csv")

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    port="5432",
    database="customer_churn_db",
    user="postgres",
    password="YOUR_ACTUAL_PASSWORD"
)

# %%
from urllib.parse import quote_plus

password = quote_plus("Kinkap@@1105")

DATABASE_URL = f"postgresql+psycopg2://postgres:{password}@localhost:5432/customer_churn_db"

engine = create_engine(DATABASE_URL)

# %%
df.to_sql(
    "telco_customer_churn",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 32
